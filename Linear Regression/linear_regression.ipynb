# %% [markdown]
# <a href="https://colab.research.google.com/github/garvinfrank/Machine-Learning-Algorithms/blob/main/Linear%20Regression/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
# 5  5000  800000
# 6  2800  500000
# 7  3100  560000

# %%
df.describe()
# Out:
#               area          price
# count     8.000000       8.000000
# mean   3412.500000  623750.000000
# std     779.079127  102076.651871
# min    2600.000000  500000.000000
# 25%    2950.000000  557500.000000
# 50%    3150.000000  587500.000000
# 75%    3700.000000  691250.000000
# max    5000.000000  800000.000000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='blue',marker = '+')

# %%
new_df = df.drop('price',axis = 'columns')
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000
# 5  5000
# 6  2800
# 7  3100

# %%
x = df.iloc[:,0]
x
# Out:
# 0    2600
# 1    3000
# 2    3200
# 3    3600
# 4    4000
# 5    5000
# 6    2800
# 7    3100
# Name: area, dtype: int64

# %%
price = df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# 5    800000
# 6    500000
# 7    560000
# Name: price, dtype: int64

# %%
model = linear_model.LinearRegression()
model.fit(new_df,price)
# Out:
# LinearRegression()

# %%
a=model.predict([[3100]])
a
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([584574.87496322])

# %%
b =model.coef_
b
# Out:
# array([125.36040012])

# %%
c = model.intercept_
c
# Out:
# 195957.63459841145

# %% [markdown]
# Y = m*x +c

# %%
3100*b+c
# Out:
# array([584574.87496322])

# %%
area_df = pd.read_csv("areas.csv")
area_df.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p = model.predict(area_df)
p
# Out:
# array([ 321318.03471609,  383998.23477493,  484286.55486908,
#         639733.451015  ,  712442.48308326,  767601.05913504,
#         884186.23124448,  629704.61900559,  791419.5351574 ,
#         484286.55486908, 1324201.23565755, 1274057.07561047,
#        1086016.47543395])

# %%
area_df['prices']=p
area_df
# Out:
#     area        prices
# 0   1000  3.213180e+05
# 1   1500  3.839982e+05
# 2   2300  4.842866e+05
# 3   3540  6.397335e+05
# 4   4120  7.124425e+05
# 5   4560  7.676011e+05
# 6   5490  8.841862e+05
# 7   3460  6.297046e+05
# 8   4750  7.914195e+05
# 9   2300  4.842866e+05
# 10  9000  1.324201e+06
# 11  8600  1.274057e+06
# 12  7100  1.086016e+06

# %%
new_area_df = df.drop('price', axis = 'columns')
new_area_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000
# 5  5000
# 6  2800
# 7  3100

# %%
new_price_df = df.drop('area', axis = 'columns')
new_price_df
# Out:
#     price
# 0  550000
# 1  565000
# 2  610000
# 3  680000
# 4  725000
# 5  800000
# 6  500000
# 7  560000

# %%
pd.read_csv("predection.csv")
# Out:
#     Unnamed: 0  area        prices
# 0            0  1000  3.213180e+05
# 1            1  1500  3.839982e+05
# 2            2  2300  4.842866e+05
# 3            3  3540  6.397335e+05
# 4            4  4120  7.124425e+05
# 5            5  4560  7.676011e+05
# 6            6  5490  8.841862e+05
# 7            7  3460  6.297046e+05
# 8            8  4750  7.914195e+05
# 9            9  2300  4.842866e+05
# 10          10  9000  1.324201e+06
# 11          11  8600  1.274057e+06
# 12          12  7100  1.086016e+06

# %%
# %matplotlib inline
# plt.xlabel("Area")
# plt.ylabel("Price")
# plt.scatter(df.new_area_df, df.new_price_df ,color  = "blue", marker= '+')
# %matplotlib inline
plt.xlabel("Area")
plt.ylabel("Price")
plt.scatter(df['area'], df['price'] ,color  = "blue", marker= '+')

# %%
df1 = pd.read_csv('homeprices.csv')
df2 = pd.read_csv('predection.csv')


plt.scatter(df1['area'], df1['price'], color='blue', marker='+', label='homeprices.csv')


plt.plot(df2['area'], df2['prices'], color='red', marker='o', label='predection.csv')

plt.xlabel('Area')
plt.ylabel('Price')
plt.legend()
plt.show()
